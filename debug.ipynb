# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes_data.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 LocationAbbr DataSource DataValueUnit  DataValue  \
# 0             0           3           ME      BRFSS             %       11.4
# 1             1           9           AL      BRFSS             %        5.0
# 2             2          21           VT      BRFSS             %        9.3
# 3             3          22           VI      BRFSS             %       12.0
# 4             4          29           MA      BRFSS             %        9.2
#
#    DataValueAlt  LowConfidenceLimit  HighConfidenceLimit TopicID QuestionID  \
# 0          11.4                10.2                 12.7     DIA      DIA01
# 1           5.0                 3.6                  6.8     DIA      DIA01
# 2           9.3                 8.0                 10.8     DIA      DIA01
# 3          12.0                 7.7                 18.2     DIA      DIA01
# 4           9.2                 8.0                 10.6     DIA      DIA01
#
# ...

# %%
dia01_counts_df = df.groupby('LocationAbbr')['QuestionID'].value_counts().reset_index()

# %%
dia01_coundia01_counts_df = df[df['QuestionID'] == 'DIA01'].groupby('LocationAbbr').size().reset_index(name='DIA01_Count')
ts_df = dia01_counts_df[dia01_counts_df['QuestionID'] == 'DIA01']
ts_df
# Out:
#     LocationAbbr QuestionID  count
# 1             AK      DIA01     66
# 5             AL      DIA01     59
# 8             AR      DIA01     71
# 12            AZ      DIA01     74
# 17            CA      DIA01     77
# 19            CO      DIA01     67
# 23            CT      DIA01     73
# 27            DC      DIA01     56
# 31            DE      DIA01     61
# 36            FL      DIA01     39
# 39            GA      DIA01     67
# 42            GU      DIA01     64
# 44            HI      DIA01     76
# 47            IA      DIA01     63
# 51            ID      DIA01     55
# 55            IL      DIA01     64
# 58            IN      DIA01     72
# 61            KS      DIA01     80
# 66            KY      DIA01     56
# 69            LA      DIA01     65
# 73            MA      DIA01     72
# 76            MD      DIA01     82
# 80            ME      DIA01     58
# 85            MI      DIA01     71
# 89            MN      DIA01     83
# 93            MO      DIA01     71
# ...
